# %% [markdown]
# # PARISYA BOKINGS _ 202131119
# ## UAS PEMBELAJARAN MESIN

# %% [markdown]
# # IMPORT LIBRARY

# %%
import pandas as parisya #memasukan library pandas
import numpy as np #menggunakan rumus matematika untuk project
import matplotlib.pyplot as plt #untuk mengimport pyplot dari matplotlob

# %% [markdown]
# # MEMBACA DATA SET

# %%
parisya = parisya.read_csv ("Churn_Modelling.csv") #membaca data menggunakan pandas
parisya
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# # MEMILIH DATA DARI DATASET UNTUK DIGUNAKAN SEBAGAI ATRIBUT X

# %%
parisya.describe() #mencari deskripsi data
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
parisya.info() #mencari info data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
parisya = parisya[["Balance", "EstimatedSalary"]] #balance= x1; estimatedSalary= x2
parisya.head(10) #menampilkan 10 baris pertama dari DataFrame yang sudah diubah
# Out:
#      Balance  EstimatedSalary
# 0       0.00        101348.88
# 1   83807.86        112542.58
# 2  159660.80        113931.57
# 3       0.00         93826.63
# 4  125510.82         79084.10
# 5  113755.78        149756.71
# 6       0.00         10062.80
# 7  115046.74        119346.88
# 8  142051.07         74940.50
# 9  134603.88         71725.73

# %%
parisya.describe() #mendeskripsikan data yang sudah diubah
# Out:
#              Balance  EstimatedSalary
# count   10000.000000     10000.000000
# mean    76485.889288    100090.239881
# std     62397.405202     57510.492818
# min         0.000000        11.580000
# 25%         0.000000     51002.110000
# 50%     97198.540000    100193.915000
# 75%    127644.240000    149388.247500
# max    250898.090000    199992.480000

# %%
fig, ax = plt.subplots() #mengubah objek figure menjadi objek axes
ax.boxplot(parisya,
          vert = False, #mengatur orientasi boxplot menjadi horizontal
          showmeans = True, #menunjukkan garis rata-rata
          meanline = True, #menunjukkan garis rata-rata sebagai garis terpisah
          labels = ("balance", "EstimatedSalary"), #mnyertakan label pada sumbu horizontal
          patch_artist = True, #mengizinkan kotak untuk diisi warna
          medianprops = {"linewidth" : 2, "color" : "orange"}, #menentukan properti untuk garis median (tengah kotak)
          meanprops = {"linewidth" : 2, "color" : "yellow"}) #mnentukan properti untuk garis rata-rata
plt.show() #menampilkan data

# %% [markdown]
# # BUANG OUTLIER

# %%
#Q1, Q3, dan IQR
kolom = ["Balance", "EstimatedSalary"]

Q1 = parisya[kolom].quantile(0.25) #menghitung kuartil pertama (Q1) untuk setiap kolom yang ada di dalam list kolom
Q3 = parisya[kolom].quantile(0.75) #menghitung kuartil ketiga (Q3) untuk setiap kolom yang ada di dalam list kolom
IQR = Q3-Q1 #enghitung Rentang Interkuartil (IQR) untuk setiap kolom yang ada di dalam list kolom
parisya = parisya[~((parisya[kolom]<(Q1 - 1.5 * IQR)) |
             (parisya[kolom]>(Q3 + 1.5 * IQR))).any(axis = 1)]

plt.boxplot(parisya[kolom]) #membuat boxplot dari data yang sudah bersih dari outlier
plt.xticks([1,2], kolom) #menetapkan label sumbu x untuk kolom yang sesuai
plt.title("Outlier Setelah Dibuang") #menetapkan judul untuk boxplot
plt.show() #menampilkan data

# %%
parisya.describe() #mendeskripsikan data
# Out:
#              Balance  EstimatedSalary
# count   10000.000000     10000.000000
# mean    76485.889288    100090.239881
# std     62397.405202     57510.492818
# min         0.000000        11.580000
# 25%         0.000000     51002.110000
# 50%     97198.540000    100193.915000
# 75%    127644.240000    149388.247500
# max    250898.090000    199992.480000

# %%
parisya.info() #informasi data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Balance          10000 non-null  float64
#  1   EstimatedSalary  10000 non-null  float64
# dtypes: float64(2)
# memory usage: 234.4 KB

# %% [markdown]
# # MEMBUAT NILAI X

# %%
x_array = np.array(parisya)

# %% [markdown]
# # VISUALISASI PERSEBARAN DATA

# %%
plt.scatter(parisya.Balance, parisya.EstimatedSalary)
plt.show()

# %% [markdown]
# # STANDARISASI DATA

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_array)
plt.scatter(x_scaled[:,0], x_scaled[:,1], s=10)
plt.show()

# %% [markdown]
# # CEK SUM OF SQUARE ERROR DARI TIAP PEMBAGIAN JUMLAH CLUSTER

# %%
from sklearn.cluster import KMeans
sse = []
index = range(1,10)
for i in index :
    kmeans = KMeans(n_clusters = i, random_state = 0, n_init='auto')
    kmeans.fit(x_scaled)
    sse_ = kmeans.inertia_
    sse.append(sse_)
    print (i,sse_)
# Out:
# 1 19999.999999999993
# 2 11358.773843501733
# 3 6650.177975309724
# 4 3898.739524294445
# 5 3036.110716180827
# 6 2697.156367286132
# 7 2421.8600814340143
# 8 2168.0576036965385
# 9 1631.9074693715963

# %%
plt.plot(index, sse)
plt.show()

# %% [markdown]
# # MEMBUAT MODEL

# %%
kmeans = KMeans (n_clusters = 3, random_state = 0, n_init='auto')
kmeans.fit(x_scaled)
# Out:
# KMeans(n_clusters=3, n_init='auto', random_state=0)

# %% [markdown]
# # MELIHAT CLUSTER PUSAT

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.71468328,  0.87270975],
#        [-1.20173319, -0.01944803],
#        [ 0.71451684, -0.86986565]])

# %% [markdown]
# # VISUALISASI PERSEBARAN DATA SETELAH CLUSTERING

# %%
output = plt.scatter(x_scaled[:,0],x_scaled[:,1], s=10, c = kmeans.labels_) #DATANYA

centers = kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], c="orange", s=10) #centroid
plt.title("KMEANS PREDIKSI CHURN NASABAH BANK")
plt.xlabel("Balance")
plt.ylabel("EstimatedSalary")
plt.colorbar(output)
plt.show()

# %%
from sklearn.metrics import davies_bouldin_score
labels = kmeans.labels_
davies_bouldin_score(x_scaled, labels)
# Out:
# 0.7122867204922277
